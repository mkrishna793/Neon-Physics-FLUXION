# %% [markdown]
# # FLUXION ICCAD 2024 Benchmark Runner (GPU Accelerated)
# This notebook compiles the FLUXION OpenCL and C++ engines on Kaggle's T4x2 environment to run large-scale benchmarks (e.g. `ariane136` with 500k gates) within a reasonable timeframe.

# %%
# !git clone https://github.com/mkrishna793/Neon-Physics-FLUXION.git
# !cd Neon-Physics-FLUXION && pip install -r requirements.txt
# !pip install pybind11 cmake pyopencl scipy numpy

# %%
# Compile the C++ Physics Plugin
# !cd Neon-Physics-FLUXION && python setup.py build_ext --inplace

# %%
# Clone the ICCAD Benchmark Database
# !git clone https://github.com/ASU-VDA-Lab/2024_ICCAD_Contest_Gate_Sizing_Benchmark.git

# %%
# Extract the required designs (e.g., ariane136)
# !cd 2024_ICCAD_Contest_Gate_Sizing_Benchmark/design && sh unzip.sh

# %%
# Run FLUXION on a large GPU-accelerated design
# !cd Neon-Physics-FLUXION && python benchmarks/run_industry_benchmarks.py --file ../2024_ICCAD_Contest_Gate_Sizing_Benchmark/design/ariane136/ariane136.def --format lefdef --steps 5000
